# %% [markdown]
# <a href="https://colab.research.google.com/github/jaggu-x26/Intermediate-Level-Task-Letsgroww/blob/main/LetsGrow_Handwritten_Digit_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
# Load and preprocess the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Reshape and normalize the image data
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255

# %%
# One-hot encode the labels
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Build the CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
model.fit(train_images, train_labels, epochs=5, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/5
# 750/750 [==============================] - 50s 65ms/step - loss: 0.2034 - accuracy: 0.9378 - val_loss: 0.0789 - val_accuracy: 0.9765
# Epoch 2/5
# 750/750 [==============================] - 46s 62ms/step - loss: 0.0577 - accuracy: 0.9819 - val_loss: 0.0568 - val_accuracy: 0.9828
# Epoch 3/5
# 750/750 [==============================] - 46s 61ms/step - loss: 0.0408 - accuracy: 0.9870 - val_loss: 0.0476 - val_accuracy: 0.9847
# Epoch 4/5
# 750/750 [==============================] - 45s 60ms/step - loss: 0.0318 - accuracy: 0.9896 - val_loss: 0.0402 - val_accuracy: 0.9881
# Epoch 5/5
# 750/750 [==============================] - 56s 75ms/step - loss: 0.0260 - accuracy: 0.9917 - val_loss: 0.0380 - val_accuracy: 0.9885

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0287 - accuracy: 0.9909
# Test accuracy: 0.9908999800682068

# %%
# Save the model
model.save('handwriting_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt

# ... (previous code)

# Train the model and collect history
history = model.fit(train_images, train_labels, epochs=5, batch_size=64, validation_split=0.2)

# Plot training history
def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# Visualize the training history
plot_training_history(history)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/5
# 750/750 [==============================] - 53s 71ms/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.0384 - val_accuracy: 0.9887
# Epoch 2/5
# 750/750 [==============================] - 47s 62ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.0430 - val_accuracy: 0.9878
# Epoch 3/5
# 750/750 [==============================] - 46s 61ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.0397 - val_accuracy: 0.9892
# Epoch 4/5
# 750/750 [==============================] - 45s 59ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 0.0443 - val_accuracy: 0.9877
# Epoch 5/5
# ...
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0341 - accuracy: 0.9910
# Test accuracy: 0.9909999966621399

# %% [markdown]
# Insights:-The tasks performed involve developing a Convolutional Neural Network (CNN) using TensorFlow to classify handwritten digits from the MNIST dataset. Let's break down the key insights gained from each part of the code:
